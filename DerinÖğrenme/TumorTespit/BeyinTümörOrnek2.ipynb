# %%
import json
import math
import os
from glob import glob 
from tqdm import tqdm
from PIL import Image
import cv2 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import tensorflow as tf
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split

from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.applications import VGG16,VGG19
from keras.utils.np_utils import to_categorical
from keras.layers import  Conv2D,MaxPool2D,MaxPooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img

# %%
input_path = "btData/"
train_path = input_path +"Train/"
test_path = input_path +"Test/"
val_path = input_path +"Val/"

batch_size=20

# %%
fig, ax = plt.subplots(1,4, figsize=(12,12))
ax = ax.ravel()
plt.tight_layout()
for i, _set in enumerate(['train', 'test']):
    set_path = input_path+_set
    ax[i].imshow(plt.imread(set_path+'/no/'+os.listdir(set_path+'/no')[0]),cmap='gray')
    ax[i].set_title('File: {} - Condition: Healthy'.format(_set))
    ax[i+2].imshow(plt.imread(set_path+'/yes/'+os.listdir(set_path+'/yes')[0]),cmap='gray')
    ax[i+2].set_title('File: {} - Condition: Infected'.format(_set))

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
      rotation_range=40,
      horizontal_flip=True,
      fill_mode='nearest' )

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=(128, 128),
        batch_size=20,
        class_mode='binary')
validation_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=(128, 128),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 2349 images belonging to 2 classes.
# Found 511 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(input_shape=(128, 128, 3), filters=32, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_219 (Conv2D)          (None, 128, 128, 32)      896
# _________________________________________________________________
# conv2d_220 (Conv2D)          (None, 128, 128, 32)      9248
# _________________________________________________________________
# conv2d_221 (Conv2D)          (None, 128, 128, 32)      9248
# _________________________________________________________________
# conv2d_222 (Conv2D)          (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_223 (Conv2D)          (None, 64, 64, 64)        18496
# _________________________________________________________________
# conv2d_224 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# conv2d_225 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_226 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_227 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_228 (Conv2D)          (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_84 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 16384)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16384)             0
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 16385
# =================================================================
# Total params: 653,985
# Trainable params: 653,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer= RMSprop(learning_rate=0.0001,decay=1e-6),
              metrics=['acc'])

# %%
history = model.fit(
train_generator,
steps_per_epoch=train_generator.samples//batch_size,
epochs=25,
validation_data=validation_generator,
validation_steps=validation_generator.samples//batch_size
)
# Out:
# Epoch 1/25
# 117/117 [==============================] - 247s 2s/step - loss: 0.5933 - acc: 0.6788 - val_loss: 0.5901 - val_acc: 0.7180
# Epoch 2/25
# 117/117 [==============================] - 248s 2s/step - loss: 0.5192 - acc: 0.7501 - val_loss: 0.5728 - val_acc: 0.7220
# Epoch 3/25
# 117/117 [==============================] - 253s 2s/step - loss: 0.4975 - acc: 0.7626 - val_loss: 0.6692 - val_acc: 0.6940
# Epoch 4/25
# 117/117 [==============================] - 261s 2s/step - loss: 0.4691 - acc: 0.7759 - val_loss: 0.5724 - val_acc: 0.7620
# Epoch 5/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.4364 - acc: 0.7995 - val_loss: 0.5750 - val_acc: 0.7740
# Epoch 6/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.4193 - acc: 0.8158 - val_loss: 0.6054 - val_acc: 0.7340
# Epoch 7/25
# 117/117 [==============================] - 264s 2s/step - loss: 0.4041 - acc: 0.8154 - val_loss: 0.6563 - val_acc: 0.7180
# Epoch 8/25
# 117/117 [==============================] - 270s 2s/step - loss: 0.3838 - acc: 0.8338 - val_loss: 0.5390 - val_acc: 0.7600
# Epoch 9/25
# 117/117 [==============================] - 261s 2s/step - loss: 0.3675 - acc: 0.8390 - val_loss: 0.6155 - val_acc: 0.7700
# Epoch 10/25
# 117/117 [==============================] - 261s 2s/step - loss: 0.3603 - acc: 0.8325 - val_loss: 0.8493 - val_acc: 0.7000
# Epoch 11/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.3387 - acc: 0.8587 - val_loss: 0.5086 - val_acc: 0.8080
# Epoch 12/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.3225 - acc: 0.8566 - val_loss: 0.4602 - val_acc: 0.8240
# Epoch 13/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.3078 - acc: 0.8699 - val_loss: 0.5729 - val_acc: 0.8020
# Epoch 14/25
# 117/117 [==============================] - 261s 2s/step - loss: 0.3085 - acc: 0.8639 - val_loss: 0.5771 - val_acc: 0.7920
# Epoch 15/25
# 117/117 [==============================] - 263s 2s/step - loss: 0.2952 - acc: 0.8742 - val_loss: 0.4217 - val_acc: 0.8320
# Epoch 16/25
# 117/117 [==============================] - 260s 2s/step - loss: 0.2846 - acc: 0.8802 - val_loss: 0.4903 - val_acc: 0.8160
# Epoch 17/25
# 117/117 [==============================] - 243s 2s/step - loss: 0.2552 - acc: 0.8948 - val_loss: 0.3968 - val_acc: 0.8300
# Epoch 18/25
# 117/117 [==============================] - 168s 1s/step - loss: 0.2467 - acc: 0.8978 - val_loss: 0.3634 - val_acc: 0.8560
# Epoch 19/25
# 117/117 [==============================] - 175s 1s/step - loss: 0.2299 - acc: 0.9128 - val_loss: 0.3781 - val_acc: 0.8540
# Epoch 20/25
# 117/117 [==============================] - 200s 2s/step - loss: 0.2235 - acc: 0.9073 - val_loss: 0.4653 - val_acc: 0.8420
# Epoch 21/25
# 117/117 [==============================] - 188s 2s/step - loss: 0.2214 - acc: 0.9090 - val_loss: 0.4840 - val_acc: 0.8340
# Epoch 22/25
# 117/117 [==============================] - 199s 2s/step - loss: 0.2079 - acc: 0.9120 - val_loss: 0.4507 - val_acc: 0.8360
# Epoch 23/25
# 117/117 [==============================] - 184s 2s/step - loss: 0.1975 - acc: 0.9197 - val_loss: 0.3833 - val_acc: 0.8700
# Epoch 24/25
# 117/117 [==============================] - 187s 2s/step - loss: 0.1946 - acc: 0.9240 - val_loss: 0.3345 - val_acc: 0.8740
# Epoch 25/25
# 117/117 [==============================] - 173s 1s/step - loss: 0.1783 - acc: 0.9279 - val_loss: 0.4027 - val_acc: 0.8840

# %%
plt.plot(history.history['val_acc'])
plt.title('model_accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_generator','validation_generator'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.save("cnn-tumor-0.8840.h5")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['acc', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
