# %%
import json
import math
import os
from glob import glob 
from tqdm import tqdm
from PIL import Image
import cv2 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import tensorflow as tf
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 
from sklearn.model_selection import train_test_split

from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, RMSprop
from keras.applications import VGG16,VGG19
from keras.utils.np_utils import to_categorical
from keras.layers import  Conv2D,MaxPool2D,MaxPooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img

# %%
input_path = "btData/"
train_path = input_path +"Train/"
test_path = input_path +"Test/"
val_path = input_path +"Val/"

batch_size=40

# %%
fig, ax = plt.subplots(1,4, figsize=(12,12))
ax = ax.ravel()
plt.tight_layout()
for i, _set in enumerate(['train', 'test']):
    set_path = input_path+_set
    ax[i].imshow(plt.imread(set_path+'/no/'+os.listdir(set_path+'/no')[0]),cmap='gray')
    ax[i].set_title('File: {} - Condition: Healthy'.format(_set))
    ax[i+2].imshow(plt.imread(set_path+'/yes/'+os.listdir(set_path+'/yes')[0]),cmap='gray')
    ax[i+2].set_title('File: {} - Condition: Infected'.format(_set))

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                rotation_range=30,
                width_shift_range=0.3,
                height_shift_range=0.3,
                zoom_range=0.3,
                fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=(256, 256),
        batch_size=20,
        class_mode='binary')
validation_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=(256, 256),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 2349 images belonging to 2 classes.
# Found 511 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(input_shape=(256, 256, 3), filters=32, kernel_size=(3, 3),padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='tanh'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='tanh'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='tanh'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='tanh'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.6))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 512)       1180160
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 1,601,345
# Trainable params: 1,601,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer= Adam(learning_rate=0.0001,decay=1e-5),
              metrics=['acc'])

# %%
history = model.fit(
train_generator,
steps_per_epoch=train_generator.samples//batch_size,
epochs=50,
validation_data=validation_generator,
validation_steps=validation_generator.samples//batch_size
)
# Out:
# Epoch 1/50
# 58/58 [==============================] - 136s 2s/step - loss: 0.6606 - acc: 0.5776 - val_loss: 0.5968 - val_acc: 0.7083
# Epoch 2/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.6436 - acc: 0.6353 - val_loss: 0.6523 - val_acc: 0.6708
# Epoch 3/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.6140 - acc: 0.6588 - val_loss: 0.5926 - val_acc: 0.6958
# Epoch 4/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.6113 - acc: 0.6675 - val_loss: 0.5861 - val_acc: 0.7000
# Epoch 5/50
# 58/58 [==============================] - 127s 2s/step - loss: 0.5855 - acc: 0.6936 - val_loss: 0.5650 - val_acc: 0.7167
# Epoch 6/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5811 - acc: 0.6871 - val_loss: 0.5781 - val_acc: 0.7208
# Epoch 7/50
# 58/58 [==============================] - 127s 2s/step - loss: 0.5717 - acc: 0.6980 - val_loss: 0.7291 - val_acc: 0.5000
# Epoch 8/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5750 - acc: 0.6832 - val_loss: 0.5550 - val_acc: 0.7375
# Epoch 9/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5823 - acc: 0.6853 - val_loss: 0.5374 - val_acc: 0.7542
# Epoch 10/50
# 58/58 [==============================] - 127s 2s/step - loss: 0.5646 - acc: 0.6963 - val_loss: 0.6194 - val_acc: 0.7042
# Epoch 11/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5650 - acc: 0.6862 - val_loss: 0.5143 - val_acc: 0.7542
# Epoch 12/50
# 58/58 [==============================] - 127s 2s/step - loss: 0.5721 - acc: 0.6954 - val_loss: 0.5361 - val_acc: 0.7500
# Epoch 13/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5675 - acc: 0.6997 - val_loss: 0.6889 - val_acc: 0.5792
# Epoch 14/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5509 - acc: 0.7147 - val_loss: 0.6058 - val_acc: 0.6458
# Epoch 15/50
# 58/58 [==============================] - 128s 2s/step - loss: 0.5649 - acc: 0.7058 - val_loss: 0.5331 - val_acc: 0.7458
# Epoch 16/50
# 58/58 [==============================] - 129s 2s/step - loss: 0.5464 - acc: 0.6991 - val_loss: 0.4809 - val_acc: 0.7667
# Epoch 17/50
# 58/58 [==============================] - 134s 2s/step - loss: 0.5379 - acc: 0.7172 - val_loss: 0.5600 - val_acc: 0.7458
# Epoch 18/50
# 58/58 [==============================] - 134s 2s/step - loss: 0.5306 - acc: 0.7155 - val_loss: 0.5098 - val_acc: 0.7375
# Epoch 19/50
# 58/58 [==============================] - 133s 2s/step - loss: 0.5362 - acc: 0.7319 - val_loss: 0.5418 - val_acc: 0.7292
# Epoch 20/50
# 58/58 [==============================] - 134s 2s/step - loss: 0.5164 - acc: 0.7345 - val_loss: 0.5749 - val_acc: 0.7500
# Epoch 21/50
# 58/58 [==============================] - 135s 2s/step - loss: 0.5301 - acc: 0.7138 - val_loss: 0.5510 - val_acc: 0.7292
# Epoch 22/50
# 58/58 [==============================] - 134s 2s/step - loss: 0.5577 - acc: 0.7095 - val_loss: 0.5527 - val_acc: 0.7417
# Epoch 23/50
# 58/58 [==============================] - 133s 2s/step - loss: 0.5237 - acc: 0.7241 - val_loss: 0.6006 - val_acc: 0.6917
# Epoch 24/50
# 58/58 [==============================] - 133s 2s/step - loss: 0.5380 - acc: 0.7285 - val_loss: 0.4744 - val_acc: 0.8083
# Epoch 25/50
# 58/58 [==============================] - 133s 2s/step - loss: 0.5066 - acc: 0.7459 - val_loss: 0.5682 - val_acc: 0.7208
# Epoch 26/50
# 58/58 [==============================] - 135s 2s/step - loss: 0.5322 - acc: 0.7293 - val_loss: 0.4733 - val_acc: 0.8208
# Epoch 27/50
# 58/58 [==============================] - 134s 2s/step - loss: 0.5385 - acc: 0.7241 - val_loss: 0.5163 - val_acc: 0.7667
# Epoch 28/50
# 58/58 [==============================] - 87s 2s/step - loss: 0.5301 - acc: 0.7319 - val_loss: 0.4949 - val_acc: 0.7917
# Epoch 29/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.5290 - acc: 0.7311 - val_loss: 0.4797 - val_acc: 0.7750
# Epoch 30/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.5224 - acc: 0.7372 - val_loss: 0.4617 - val_acc: 0.7917
# Epoch 31/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4992 - acc: 0.7450 - val_loss: 0.5127 - val_acc: 0.7583
# Epoch 32/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.5265 - acc: 0.7276 - val_loss: 0.6605 - val_acc: 0.6083
# Epoch 33/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.5211 - acc: 0.7405 - val_loss: 0.4828 - val_acc: 0.7708
# Epoch 34/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4967 - acc: 0.7537 - val_loss: 0.5116 - val_acc: 0.7708
# Epoch 35/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4932 - acc: 0.7572 - val_loss: 0.5139 - val_acc: 0.7458
# Epoch 36/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.5060 - acc: 0.7563 - val_loss: 0.5155 - val_acc: 0.8000
# Epoch 37/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4965 - acc: 0.7629 - val_loss: 0.5317 - val_acc: 0.7583
# Epoch 38/50
# 58/58 [==============================] - 78s 1s/step - loss: 0.4985 - acc: 0.7685 - val_loss: 0.4593 - val_acc: 0.8000
# Epoch 39/50
# 58/58 [==============================] - 78s 1s/step - loss: 0.4977 - acc: 0.7589 - val_loss: 0.5385 - val_acc: 0.7417
# Epoch 40/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4838 - acc: 0.7772 - val_loss: 0.6760 - val_acc: 0.6417
# Epoch 41/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.5027 - acc: 0.7526 - val_loss: 0.5077 - val_acc: 0.7583
# Epoch 42/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4829 - acc: 0.7546 - val_loss: 0.4752 - val_acc: 0.7750
# Epoch 43/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4849 - acc: 0.7621 - val_loss: 0.4793 - val_acc: 0.8000
# Epoch 44/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4802 - acc: 0.7853 - val_loss: 0.5592 - val_acc: 0.7375
# Epoch 45/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4844 - acc: 0.7707 - val_loss: 0.5661 - val_acc: 0.6917
# Epoch 46/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4693 - acc: 0.7647 - val_loss: 0.5374 - val_acc: 0.7500
# Epoch 47/50
# 58/58 [==============================] - 80s 1s/step - loss: 0.4894 - acc: 0.7641 - val_loss: 0.5347 - val_acc: 0.7292
# Epoch 48/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4793 - acc: 0.7681 - val_loss: 0.5035 - val_acc: 0.7667
# Epoch 49/50
# 58/58 [==============================] - 78s 1s/step - loss: 0.4847 - acc: 0.7711 - val_loss: 0.5682 - val_acc: 0.7417
# Epoch 50/50
# 58/58 [==============================] - 79s 1s/step - loss: 0.4883 - acc: 0.7793 - val_loss: 0.4952 - val_acc: 0.7958

# %%
plt.plot(history.history['val_acc'])
plt.title('model_accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_generator','validation_generator'], loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.save("cnn-tumor-0.7958.h5")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['acc', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
